# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahcodebyte/Credit-Card-Fraud-Detection/blob/main/CreditCard_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Dependencies**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **Data Collection**

# %%
dataset = pd.read_csv('/content/creditcard.csv')

# %% [markdown]
# # **Data Preprocessing and Analysis**

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  194194.000000  194194.000000  194194.000000  194194.000000
# mean    68813.763170      -0.115439       0.007428       0.349101
# std     33460.410286       1.887772       1.620690       1.439419
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     43692.000000      -0.965423      -0.576524      -0.289391
# 50%     66070.000000      -0.104569       0.084271       0.514603
# 75%     87110.750000       1.208643       0.784954       1.236743
# max    130474.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  194194.000000  194194.000000  194194.000000  194194.000000
# mean        0.083938      -0.122675       0.049016      -0.056465
# std         1.396242       1.358257       1.307784       1.214478
# min        -5.683171     -42.147898     -26.160506     -43.557242
# ...

# %%
dataset.nunique()
# Out:
# Time       87690
# V1        188505
# V2        188505
# V3        188505
# V4        188505
# V5        188505
# V6        188505
# V7        188505
# V8        188505
# V9        188505
# V10       188505
# V11       188505
# V12       188505
# V13       188505
# V14       188505
# V15       188505
# V16       188505
# V17       188505
# V18       188505
# V19       188505
# V20       188505
# V21       188505
# V22       188505
# V23       188505
# V24       188504
# V25       188504
# V26       188504
# V27       188504
# V28       188504
# Amount     27224
# Class          2
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194194 entries, 0 to 194193
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    194194 non-null  float64
#  1   V1      194194 non-null  float64
#  2   V2      194194 non-null  float64
#  3   V3      194194 non-null  float64
#  4   V4      194194 non-null  float64
#  5   V5      194194 non-null  float64
#  6   V6      194194 non-null  float64
#  7   V7      194194 non-null  float64
#  8   V8      194194 non-null  float64
#  9   V9      194194 non-null  float64
#  10  V10     194194 non-null  float64
#  11  V11     194194 non-null  float64
#  12  V12     194194 non-null  float64
#  13  V13     194194 non-null  float64
#  14  V14     194194 non-null  float64
#  15  V15     194194 non-null  float64
#  16  V16     194194 non-null  float64
#  17  V17     194194 non-null  float64
#  18  V18     194194 non-null  float64
#  19  V19     194194 non-null  float64
# ...

# %%
dataset.isnull()
# Out:
#          Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 194189  False  False  False  False  False  False  False  False  False  False
# 194190  False  False  False  False  False  False  False  False  False  False
# 194191  False  False  False  False  False  False  False  False  False  False
# 194192  False  False  False  False  False  False  False  False  False  False
# 194193  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
dataset.fillna(dataset.mean())
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0            0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 194189  130473.0 -2.020698  1.776253 -1.065479 -2.769201 -0.064483 -0.870269
# 194190  130473.0  2.043725 -0.099641 -1.174763  0.223753  0.079134 -0.704267
# 194191  130474.0  1.842498 -0.752856  1.137319  2.390623 -1.447940  0.953968
# 194192  130474.0  2.168959 -1.157163 -1.043238 -1.217888 -0.472766  0.536149
# 194193  130474.0 -0.301503  0.604028 -0.067684 -0.450046  0.662453 -0.282373
#
# ...

# %%
dataset['Class'].value_counts()
# Out:
# 0.0    193812
# 1.0       381
# Name: Class, dtype: int64

# %% [markdown]
# 0-> Normal Transaction
# 1-> Fraudulent Transaction

# %%
legit = dataset[dataset.Class==0]
fraud = dataset[dataset.Class==1]

# %%
legit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
fraud.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
legit.Amount.describe()
# Out:
# count    193812.000000
# mean         89.425440
# std         248.512542
# min           0.000000
# 25%           5.990000
# 50%          22.900000
# 75%          79.000000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     381.000000
# mean      116.421155
# std       247.034583
# min         0.000000
# 25%         1.000000
# 50%        11.400000
# 75%       104.030000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    68829.705849 -0.104350 -0.000903  0.365061  0.074709 -0.114775
# 1.0    60541.997375 -5.755911  4.243874 -7.768470  4.780104 -4.143295
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.051884 -0.043405  0.018985  0.015904  ...  0.020889 -0.018183
# 1.0   -1.408967 -6.702717  0.703757 -2.780511  ...  0.382486  0.798233
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.053682 -0.017107  0.005055  0.065969  0.007215  0.000952  0.002047
# 1.0   -0.021515 -0.038763 -0.066856  0.074069  0.041146  0.177640  0.056083
#
#            Amount
# Class
# 0.0     89.425440
# 1.0    116.421155
#
# [2 rows x 30 columns]

# %% [markdown]
# Creating the dataset with even amount of legit and fraudulent ttransaction.

# %%
legit_sample = legit.sample(n=381)

# %% [markdown]
# Joining the two datasets.

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 119628  75523.0 -0.606070  1.217374  1.074546 -0.179711  0.240622 -0.506782
# 83624   59946.0 -0.315428  0.361952  1.264969 -0.683855 -0.271205 -0.310224
# 73473   55150.0 -0.492135  0.791140  2.088211  0.677764  0.500120  0.059689
# 14358   25468.0  1.108268  0.575115  0.168783  2.381818  0.278054 -0.174329
# 14159   25176.0  1.118040  0.146961  0.531680  1.497404 -0.155250  0.157532
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 119628  0.568917  0.105907 -0.445382  ... -0.262540 -0.657842 -0.055784
# 83624   0.239567 -0.040083 -1.508962  ...  0.076260  0.251178 -0.054380
# 73473   0.429330 -0.236991 -0.341466  ... -0.094621 -0.075553 -0.354440
# 14358   0.355226  0.028287 -1.225547  ...  0.075700  0.136880 -0.062557
# 14159  -0.229275  0.139370  1.551938  ... -0.216858 -0.259937 -0.046994
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    381
# 1.0    381
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    69167.595801 -0.148640 -0.008262  0.384499  0.060405 -0.098832
# 1.0    60541.997375 -5.755911  4.243874 -7.768470  4.780104 -4.143295
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.050007 -0.114493  0.020433 -0.061122  ...  0.038949 -0.003658
# 1.0   -1.408967 -6.702717  0.703757 -2.780511  ...  0.382486  0.798233
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.036055 -0.019777  0.016911  0.114691 -0.014926  0.000548  0.007495
# 1.0   -0.021515 -0.038763 -0.066856  0.074069  0.041146  0.177640  0.056083
#
#            Amount
# Class
# 0.0     80.001995
# 1.0    116.421155
#
# [2 rows x 30 columns]

# %% [markdown]
# # **Splitting data into training and testing data**

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %% [markdown]
# # **Model Creation and Training**

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # **Model Evaluation**

# %% [markdown]
# Evaluation on training data.

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print(training_data_accuracy*100)
# Out:
# 95.07389162561576

# %% [markdown]
# Evaluation on test data.

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print(testing_data_accuracy*100)
# Out:
# 94.77124183006535

# %% [markdown]
# Support Vector:

# %%
from sklearn.svm import SVC
mod=SVC(kernel='linear')

# %%
mod.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
prediction = mod.predict(X_test)

# %%
score = accuracy_score(prediction, Y_test)
score*100
# Out:
# 93.4640522875817
